# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df[df["Type 1"]=="Grass"]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
new_df=df.loc[df["Type 1"]=="Grass"]

# %%
new_df.to_excel("type1asGrass.xlsx")

# %%
new_df1=df[(df["Type 1"]=="Grass")&(df["Type 2"]=="Poison")]

# %%
new_df1
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
(df["Type 1"]=="Grass")&(df["Type 2"]=="Poison")
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Length: 800, dtype: bool

# %%
new_df1.to_excel("type1asGrassAndtype2asPoison.xlsx")

# %%
new_df1.reset_index()
# Out:
#     index    #                   Name Type 1  Type 2   HP  Attack  Defense  \
# 0       0    1              Bulbasaur  Grass  Poison   45      49       49
# 1       1    2                Ivysaur  Grass  Poison   60      62       63
# 2       2    3               Venusaur  Grass  Poison   80      82       83
# 3       3    3  VenusaurMega Venusaur  Grass  Poison   80     100      123
# 4      48   43                 Oddish  Grass  Poison   45      50       55
# 5      49   44                  Gloom  Grass  Poison   60      65       70
# 6      50   45              Vileplume  Grass  Poison   75      80       85
# 7      75   69             Bellsprout  Grass  Poison   50      75       35
# 8      76   70             Weepinbell  Grass  Poison   65      90       50
# 9      77   71             Victreebel  Grass  Poison   80     105       65
# 10    344  315                Roselia  Grass  Poison   50      60       45
# ...

# %%
new_df1
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
new_df1=new_df1.reset_index(drop = True)

# %%
new_df1
# Out:
#     index    #                   Name Type 1  Type 2   HP  Attack  Defense  \
# 0       0    1              Bulbasaur  Grass  Poison   45      49       49
# 1       1    2                Ivysaur  Grass  Poison   60      62       63
# 2       2    3               Venusaur  Grass  Poison   80      82       83
# 3       3    3  VenusaurMega Venusaur  Grass  Poison   80     100      123
# 4      48   43                 Oddish  Grass  Poison   45      50       55
# 5      49   44                  Gloom  Grass  Poison   60      65       70
# 6      50   45              Vileplume  Grass  Poison   75      80       85
# 7      75   69             Bellsprout  Grass  Poison   50      75       35
# 8      76   70             Weepinbell  Grass  Poison   65      90       50
# 9      77   71             Victreebel  Grass  Poison   80     105       65
# 10    344  315                Roselia  Grass  Poison   50      60       45
# ...

# %%
new_df1.drop('a', inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 new_df1.drop('a', inplace=True, axis=1)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5388, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5240 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...
